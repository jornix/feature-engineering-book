# %%
import numpy as np

# %%
small_counts = np.random.randint(0, 100, 20)
small_counts
# Out:
# array([34, 78, 56, 22, 69, 11, 63, 34, 36, 69, 80, 25, 54, 47, 82, 15,  2,
#        13,  2, 42])

# %%
np.floor_divide(small_counts, 10)
# Out:
# array([3, 7, 5, 2, 6, 1, 6, 3, 3, 6, 8, 2, 5, 4, 8, 1, 0, 1, 0, 4])

# %%
large_counts = [296, 8286, 64011, 80, 3, 725, 867, 2215, 7689, 11495, 91897, 44, 28, 7971, 926, 122, 22222]

# %%
np.floor(np.log10(large_counts))
# Out:
# array([2., 3., 4., 1., 0., 2., 2., 3., 3., 4., 4., 1., 1., 3., 2., 2., 4.])

# %%
import pandas as pd

# %%
pd.qcut(large_counts, 4, labels=False)
# Out:
# array([1, 2, 3, 0, 0, 1, 1, 2, 2, 3, 3, 0, 0, 2, 1, 0, 3])

# %%
large_counts_series = pd.Series(large_counts)
large_counts_series.quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     122.0
# 0.50     926.0
# 0.75    8286.0
# dtype: float64

# %%
import pandas as pd
import json

# %%
biz_f = open('data/yelp_academic_dataset_business.json')
biz_df = pd.DataFrame([json.loads(x) for x in biz_f.readlines()])
biz_f.close()

# %%
biz_df['review_count'].max()
# Out:
# 1170

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
biz_df['review_count'].hist(ax=ax, bins=100)
ax.set_yscale('log')
ax.tick_params(labelsize=14)
ax.set_xlabel('Review Count', fontsize=14)
ax.set_ylabel('Occurrence', fontsize=14)
# Out:
# <div id='ff762b1d-fd4e-4116-9bf9-6c380e5e02ed'></div>
# Text(0, 0.5, 'Occurrence')

# %%
deciles = biz_df['review_count'].quantile([.1, .2, .3, .4, .5, .6, .7, .8, .9])
deciles
# Out:
# 0.1     3.0
# 0.2     3.0
# 0.3     4.0
# 0.4     5.0
# 0.5     6.0
# 0.6     8.0
# 0.7    13.0
# 0.8    24.0
# 0.9    56.0
# Name: review_count, dtype: float64

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
biz_df['review_count'].hist(ax=ax, bins=100)
for pos in deciles:
    handle = plt.axvline(pos, color='r')
ax.legend([handle], ['deciles'], fontsize=14)
ax.set_yscale('log')
ax.set_xscale('log')
ax.tick_params(labelsize=14)
ax.set_xlabel('Review Count', fontsize=14)
ax.set_ylabel('Occurrence', fontsize=14)
# Out:
# <div id='a94e9c8b-105e-4d0a-ba9a-02e61edaa7a8'></div>
# Text(0, 0.5, 'Occurrence')

# %%
import numpy as np

# %%
y = np.arange(0.00001, 3, 0.01)
x = np.power(10, y)

# %%
fig, ax = plt.subplots()
plt.plot(x, y, 'b')
ax.tick_params(labelsize=14)
ax.set_xlabel('x', fontsize=14)
ax.set_ylabel('log10(x)', fontsize=14)
# Out:
# <div id='828a0523-ba68-4449-90af-92edd08bb497'></div>
# Text(0, 0.5, 'log10(x)')

# %%
log_review_count = np.log10(biz_df['review_count'] + 1)

# %%
plt.figure()
ax = plt.subplot(2,1,1)
biz_df['review_count'].hist(ax=ax, bins=100)
ax.tick_params(labelsize=14)
ax.set_xlabel('review_count', fontsize=14)
ax.set_ylabel('Occurrence', fontsize=14)

ax = plt.subplot(2,1,2)
log_review_count.hist(ax=ax, bins=100)
ax.tick_params(labelsize=14)
ax.set_xlabel('log10(review_count))', fontsize=14)
ax.set_ylabel('Occurrence', fontsize=14)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Occurrence')

# %%
biz_df
# Out:
#                   business_id  \
# 0      O_X3PGhk3Y5JWVi866qlJg
# 1      QbrM7wqtmoNncqjc6GtFaQ
# 2      7lbvsGKzhjuX3oJtaXJvOg
# 3      gjxoKVsRJwEoa8zd9XxlAw
# 4      V28yjMqyZnbCtabroJN_aA
# ...                       ...
# 15580  gfSNqTICrdeewK8XINGSaA
# 15581  mDrnZvSXMbMIGE0IX9mMqA
# 15582  Lk4WdkxGMZAE0EpYKExIGA
# 15583  cmmbUO5ghhSQzqeOkyfMnw
# 15584  7_y_M5wRaSvNXt-q4xvlEQ
#
#                                             full_address  \
# 0                      1501 W Bell Rd\nPhoenix, AZ 85023
# 1                18501 N 83rd Avenue\nGlendale, AZ 85308
# 2      5000 S Arizona Mills Cir\nSte 590\nTempe, AZ 8...
# 3                  912 W Sycamore Pl\nChandler, AZ 85225
# 4                 1745 W Glendale Ave\nPhoenix, AZ 85021
# ...                                                  ...
# 15580                  1909 E Ray Rd\nChandler, AZ 85225
# 15581                    115 N 6th St\nPhoenix, AZ 85004
# 15582                  2401 E Bell Rd\nPhoenix, AZ 85032
# 15583    13371 W Grand Ave Ste C-101\nSurprise, AZ 85374
# 15584             1733 W Van Buren St\nPhoenix, AZ 85007
#
#                                                    hours  open  \
# 0      {'Monday': {'close': '18:00', 'open': '11:00'}...  True
# 1                                                     {}  True
# 2      {'Monday': {'close': '21:00', 'open': '10:00'}...  True
# 3      {'Monday': {'close': '19:00', 'open': '06:00'}...  True
# 4                                                     {}  True
# ...                                                  ...   ...
# 15580  {'Tuesday': {'close': '14:30', 'open': '11:30'...  True
# 15581                                                 {}  True
# 15582                                                 {}  True
# 15583  {'Monday': {'close': '19:00', 'open': '11:00'}...  True
# 15584                                                 {}  True
#
#                                               categories      city  \
# 0      [Active Life, Arts & Entertainment, Stadiums &...   Phoenix
# 1      [Tires, Automotive, Fashion, Shopping, Departm...  Glendale
# 2      [Women's Clothing, Men's Clothing, Fashion, Sh...     Tempe
# 3         [Pet Services, Pet Boarding/Pet Sitting, Pets]  Chandler
# 4                                  [Veterinarians, Pets]   Phoenix
# ...                                                  ...       ...
# 15580                [Sushi Bars, Japanese, Restaurants]  Chandler
# 15581  [Active Life, Landmarks & Historical Buildings...   Phoenix
# 15582                         [Food, Convenience Stores]   Phoenix
# 15583                          [Shopping, Mobile Phones]  Surprise
# 15584                             [Mexican, Restaurants]   Phoenix
#
#        review_count                           name neighborhoods   longitude  \
# 0                29      Turf Paradise Race Course            [] -112.092329
# 1                 3        Sam's Club Members Only            [] -112.234755
# 2                 7                     Forever 21            [] -111.964485
# 3                 4          Loving Hands Pet Care            [] -111.857818
# 4                 3  Amec Mid-City Animal Hospital            [] -112.097232
# ...             ...                            ...           ...         ...
# 15580            83                          Taiko            [] -111.809582
# 15581            18                Heritage Square            [] -112.065493
# 15582             3         Glacier Water Services            [] -112.030416
# 15583             5                         Sprint            [] -112.341856
# 15584            27           La Canasta Capitolio            [] -112.097209
#
#       state  stars   latitude  \
# 0        AZ    4.0  33.638573
# 1        AZ    3.5  33.648545
# 2        AZ    3.5  33.383123
# 3        AZ    5.0  33.356472
# 4        AZ    5.0  33.538493
# ...     ...    ...        ...
# 15580    AZ    4.0  33.319907
# 15581    AZ    4.0  33.450206
# 15582    AZ    3.5  33.640146
# 15583    AZ    2.0  33.631805
# 15584    AZ    3.0  33.451256
#
#                                               attributes      type
# 0      {'Take-out': False, 'Wi-Fi': 'free', 'Good For...  business
# 1      {'Parking': {'garage': False, 'street': False,...  business
# 2      {'Parking': {'garage': False, 'street': False,...  business
# 3                                                     {}  business
# 4                                                     {}  business
# ...                                                  ...       ...
# 15580  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  business
# 15581                            {'Good for Kids': True}  business
# 15582  {'Parking': {'garage': False, 'street': False,...  business
# 15583  {'Parking': {'garage': False, 'street': False,...  business
# 15584  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...  business
#
# [15585 rows x 15 columns]

# %%
biz_df['log_review_count'] = np.log(biz_df['review_count'] + 1)

# %%
biz_train, biz_validate = cross_validation.train_test_split(biz_df, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0eff27abe17d> in <module>
# ----> 1 biz_train, biz_validate = cross_validation.train_test_split(biz_df, test_size=0.2)
#
# NameError: name 'cross_validation' is not defined

# %%
m1 = sklearn.linear_model.LinearRegression()
m1.fit(biz_train[['log_review_count']], biz_train['stars'])
m2 = sklearn.linear_model.LinearRegression()
m2.fit(biz_train[['review_count']], biz_train['stars'])

# %%
print("Residual sum of squares: %.5f"
      % np.mean((m1.predict(biz_validate[['log_review_count']]) - biz_validate['stars']) ** 2))

# %%
print("Residual sum of squares: %.5f"
      % np.mean((m2.predict(biz_validate[['review_count']]) - biz_validate['stars']) ** 2))

# %% [markdown]
# ## Bike Sharing Dataset

# %%
bike_df = pd.read_csv('data/bike_sharing/train.csv')
bike_df

# %%
fig, ax = plt.subplots()
bike_df['count'].hist(ax=ax, bins=100)

# %%
from sklearn import linear_model
from sklearn import cross_validation

# %%
categorical_cols = ['season', 'weather']
bike_df = pd.get_dummies(bike_df, prefix=categorical_cols, columns=categorical_cols)

# %%
bike_df

# %%
bike_df['log_count'] = np.log(bike_df['count'])

# %%
features = ['holiday', 'workingday', 'temp', 'atemp', 'humidity', 'windspeed',
            'season_1', 'season_2', 'season_3', 'season_4',
            'weather_1', 'weather_2', 'weather_3', 'weather_4']
train, validate = cross_validation.train_test_split(bike_df, test_size=0.2)

# %%
validate.shape

# %%
train.shape

# %%
lin_model = linear_model.LinearRegression()
lin_model.fit(train[features], train['count'])
log_lin_model = linear_model.LinearRegression()
log_lin_model.fit(train[features], train['log_count'])

# %%
# The sum of squares of the log residual errors
print("Log residual sum of squares: %.2f"
      % np.mean((np.log(1+lin_model.predict(validate[features])) - np.log(1+validate['count'])) ** 2))

# %%
# The sum of squares of the log residual errors
print("Log residual sum of squares: %.2f"
      % np.mean((np.log(1+np.exp(log_lin_model.predict(validate[features]))) - np.log(1+validate['count'])) ** 2))

# %% [markdown]
# ## Kaggle loan data

# %%
loan_df = pd.read_csv('data/Kaggle loan/loan.csv')

# %%
loan_df.ix[:, range(20)]

# %%
loan_df.ix[:, range(20,40)]

# %%
loan_df.ix[:, range(40,60)]

# %%
loan_df.ix[:, range(60, 74)]

# %%
plt.figure()
loan_df['loan_amnt'].hist(bins=100)
